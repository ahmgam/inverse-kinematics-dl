# %% [markdown]
# # Introduction
#
# Robotic arm kinematics is the relation between actiuators variables (angle of rotation or distance of extention) and the position in space, Forward kinematics is the relation between angles or distances as an input, and the position in space as an output.
#
# Forward kinematics can be represented as a set of linear transformations which maps the position of the base to the position of the end-effector with respect to world coordinates.
#
# For this project, we will work on **4DoF Articualted robotic arm** , we now drive these transformations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# By applying the Denavit-Hartenberg (DH) notations, we construct the DH table
#
# | Frame(i) | $a_i$ | $\alpha_i$ | $d_i$ | $\theta_i$ |
# |----------|-----|-------|-----|----------|
# | 1        | 0   | 90    | $l_1$ | $\theta_1$ |
# | 2        | $l_2$ | 0     | 0   | $\theta_2$ |
# | 3        | $l_3$ | 0     | 0   | $\theta_3$ |
# | 4        | $l_4$ | 0     | 0   | $\theta_4$ |
#
#  $$ ^{i-1}T_{i}=\begin{bmatrix} cos θ_i & -sinθ_i cosα_i  & sinθ_i sinα_i & a_i cosθ_i\\ sin θ_i & cosθ_i cosα_i  & -cosθ_i sinα_i & a_i sinθ_i \\ 0 & sinα_i & cosα_i &d_i \\ 0 & 0 & 0 &1\end{bmatrix}$$
#
#  $^{0}T_{4} =^{0}T_{1} ^{1}T_{2} ^{2}T_{3} ^{3}T_{4} $
#
#  $ p_1 = ^{0}T_{4} p_0 $
#
# so we can calculate each transformation matrix

# %% [markdown]
# the first :
#  $$ ^{0}T_{1}=\begin{bmatrix} cos θ_1 & 0  & sinθ_1 & 0\\ sin θ_1 & 0  & -cosθ_1 & 0 \\ 0 & 1 & 0 &l_1 \\ 0 & 0 & 0 &1\end{bmatrix}$$

# %% [markdown]
#  the second :
#   $$ ^{1}T_{2}=\begin{bmatrix} cos θ_2 & -sinθ_2  & 0 & l_2 cosθ_2\\ sin θ_2 & cosθ_2  & 0 & l_2 sinθ_2 \\ 0 & 0 & 1 & 0 \\ 0 & 0 & 0 &1\end{bmatrix}$$

# %% [markdown]
# the third :
#    $$ ^{2}T_{3}=\begin{bmatrix} cos θ_3 & -sinθ_3  & 0 & l_3 cosθ_3\\ sin θ_3 & cosθ_3  & 0 & l_3 sinθ_3 \\ 0 & 0 & 1 & 0 \\ 0 & 0 & 0 &1\end{bmatrix}$$

# %% [markdown]
# the forth :
#
# $$ ^{3}T_{4}=\begin{bmatrix} cos θ_4 & -sinθ_4  & 0 & l_4 cosθ_4\\ sin θ_4 & cosθ_4  & 0 & l_4 sinθ_4 \\ 0 & 0 & 1 & 0 \\ 0 & 0 & 0 &1\end{bmatrix}$$

# %% [markdown]
# Inverse Kinematics is the relation between position as an input and angles as an output, Inverse kinematics is drived using trigonometric relations, so It could be complex to drive and highly non-linear equation.
#
# We present using **Neural Networks** as a general approximation for inverse kinematics equations.
#
# Neural networks -as any machine learning algorithm - needs data to learn from, we will use forward kinematics equations to generate data for model training.
#
# this is the general pipeline we use in this project

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Training Dataset

# %% [markdown]
# Dataset should contain the angles and positions in the reachable range of the robotic arm.
#
#
# so data will be like this :
#
# *   Input : (position)
# *   Output : (angles)
#
# data points should be normalized, from 0 to 1, for angles, normalizing base is $2 \pi$ , so any angle will be divided by this value to be from 0 to 1.
#
# for positions, It can't be more than the sum of all links legnthes, so any position would be divided by the sum of all legnthes.
#
# now we start to **generate dataset for Reachable positions**.

# %%
# !pip install array_to_latex
# Out:
# Requirement already satisfied: array_to_latex in /usr/local/lib/python3.7/dist-packages (0.82)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from array_to_latex) (1.21.5)
# Requirement already satisfied: clipboard in /usr/local/lib/python3.7/dist-packages (from array_to_latex) (0.0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from array_to_latex) (1.3.5)
# Requirement already satisfied: pyperclip>=1.3 in /usr/local/lib/python3.7/dist-packages (from clipboard->array_to_latex) (1.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->array_to_latex) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->array_to_latex) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->array_to_latex) (1.15.0)

# %%
import sys
import numpy as np
from numpy import cos,sin,pi,arctan2,sqrt
import array_to_latex as art
np.set_printoptions(precision=3,suppress=True)
from IPython.display import Latex,display_latex

# %%
Latex(r"""""")

# %%
class Transform:
  def __init__(self,array=np.identity(4)):
    self.transform = array

  def __mul__(self, other):
    return Transform(self.transform @ other.transform)
  
  def __str__(self):
    return str(self.transform)


  def latex(self):
    if 'array_to_latex' not in sys.modules:  
      return str(self.transform)
    else :
      #Latex(art.to_ltx(self.transform, print_out=False))
      display_latex(art.to_ltx(self.transform, print_out=False),raw=True)


  def ComputeAngles(self):
    return np.array([
     arctan2(self.transform[2][1],self.transform[2][2]),
     arctan2(-self.transform[2][0],sqrt(self.transform[2][1]**2 +self.transform[2][2]**2 )),
     arctan2(self.transform[1][0],self.transform[0][0])
    ])
  def inverse(self):
    t = self.transform[:3,:3]
    inv = np.identity(4)
    inv[:3,:3]=t.T
    inv[:,3]=t.T @ (-self.transform[:,3])
    return Transform(inv)

# %%
class Joint:

  

  def CalculateTransform(self):
    self.transform=Transform( np.array( [
            [cos(self.theta),-1*sin(self.theta)*cos(self.alpha),sin(self.theta)*sin(self.alpha),self.a*cos(self.theta)],
            [sin(self.theta),cos(self.theta)*cos(self.alpha),-1*cos(self.theta)*sin(self.alpha),self.a*sin(self.theta)],
            [0,sin(self.alpha),cos(self.alpha),self.d],
            [0,0,0,1]
            ]))
    

  def ShowParameters(self):
      print("a : ",self.a," , ")
      print("alpha : ",self.alpha," , ")
      print("d : ",self.d," , ")
      print("theta : ",self.theta," , ")
      print("type : ",self.jtype)
      print(" | \n ")

# %%
class PrismaticJoint (Joint) :
  def __init__(self,alpha,a,theta):
    self.transform = Transform (np.identity(4))
    self.alpha = alpha * (pi/180)
    self.a = a
    self.theta = theta * (pi/180)
    self.jtype = "Prismatic"

  def GetTransform(self,d):
    self.d= d
    self.CalculateTransform()
    return self.transform

# %%
class RevolveJoint (Joint):
  def __init__(self,alpha,a,d):
    self.transform = Transform (np.identity(4))
    self.alpha = alpha * (pi/180)
    self.a = a
    self.d = d
    self.jtype = "Revolve"
  
  def GetTransform(self,theta):
    self.theta = theta*(np.pi/180)
    self.CalculateTransform()
    return self.transform

# %%
class ForwardKinematics :
  def __init__(self,DH_table):
    self.__Result=1
    self.__maxlength = 0
    self.transforms = []
    for t in DH_table:
      self.AddTransform(t['type'],t['a'],t['alpha'],t['d'],t['theta'])

  def ShowDH (self):
    print("number,a,alpha,d,theta")
    for t in range(len(self.transforms)):
      print( t , " : ")
      self.transforms[t].ShowParameters()

  def AddTransform (self,jtype,a,alpha,d,theta):
    if jtype =='prismatic':
      self.transforms.append(PrismaticJoint(alpha,a,theta))
    elif jtype =='revolve':
      self.transforms.append(RevolveJoint(alpha,a,d))
    else :
      raise AssertionError("Invalid joint type")

  def RemoveTransform(self,i):
    del self.transforms[i]

  def Compute(self,angles):
    if len(angles)!= len(self.transforms):
      raise AssertionError("the angles is not equal to transforms")
    self.__Result = Transform()
    for t in range (len(self.transforms)):
      self.__Result =self.transforms[len(self.transforms)-1-t].GetTransform(angles[len(self.transforms)-1-t]) * self.__Result

    return self.__Result

# %%
#define links dimentions

l1 =1
l2 =1
l3 =1
l4 =1

#define D-H table parameters
dh =  [
    {'alpha': 90, 'a': 0,   'theta': 0, 'd': l1,  'type': 'revolve'},
    {'alpha': 0,  'a': l2,  'theta': 0, 'd': 0,   'type': 'revolve'},
    {'alpha': 0,  'a': l3,  'theta': 0, 'd': 0,   'type': 'revolve'},
    {'alpha': 0,  'a': l4,  'theta': 0, 'd': 0,   'type': 'revolve'},
      ]

kc=ForwardKinematics(dh)

# %%
res = kc.Compute([60,0,0,0])
print(res)
# Out:
# [[ 0.5   -0.     0.866  1.5  ]
#  [ 0.866  0.    -0.5    2.598]
#  [ 0.     1.     0.     1.   ]
#  [ 0.     0.     0.     1.   ]]

# %%
res.latex()
# Out:
# \begin{bmatrix}
#   0.50 & -0.00 &  0.87 &  1.50\\
#   0.87 &  0.00 & -0.50 &  2.60\\
#   0.00 &  1.00 &  0.00 &  1.00\\
#   0.00 &  0.00 &  0.00 &  1.00
# \end{bmatrix}

# %%
def CreateDataPoints(X,Y,Kinematics,angles,DoF,Step,Offset,Resolution):
  for i in range(Resolution):
    if DoF==1 :
      x = Kinematics.Compute(angles)
      X.append(x)
      Y.append(angles[:4].copy())      
    else :
      X,Y= CreateDataPoints(X,Y,Kinematics,angles,DoF-1,Step,Offset,Resolution)
    angles[-(DoF-1)] = Offset[-(DoF-1)] + (i+1) * Step[-(DoF-1)]
  return X,Y

# %%
def CreateNewDataset(DoF,Resolution,Kinematics,Range):
  X = []
  Y=[]
  step = (Range[:,1]-Range[:,0])/Resolution
  offset = Range[:,0]
  angles = np.zeros(DoF)

  X,Y = CreateDataPoints(X,Y,Kinematics,angles,DoF,step,offset,Resolution)

  return np.array(X),np.array(Y)

# %%
ranges = np.array([[0,90],[-90,90],[-90,0],[-90,0]])
X,Y=CreateNewDataset(4,30,kc,ranges)
print(X.shape)
# Out:
# (810000,)

# %%
def SaveToCSV(X,Y,SavePath):
  data = np.column_stack((X.transform[:3,3],Y))
  np.savetxt(SavePath, data,fmt='%1.3f', delimiter=',')

# %%
#SaveToCSV(X,Y,"file.csv")

# %%
X
# Out:
# array([<__main__.Transform object at 0x7fe1c530fd10>,
#        <__main__.Transform object at 0x7fe1c530fcd0>,
#        <__main__.Transform object at 0x7fe2592e4b10>, ...,
#        <__main__.Transform object at 0x7fe1b3360110>,
#        <__main__.Transform object at 0x7fe1b3360150>,
#        <__main__.Transform object at 0x7fe1b3360190>], dtype=object)

# %%
Y
# Out:
# array([[ 0.,  0.,  0.,  0.],
#        [ 3.,  0.,  0.,  0.],
#        [ 6.,  0.,  0.,  0.],
#        ...,
#        [81., 84., -3., -3.],
#        [84., 84., -3., -3.],
#        [87., 84., -3., -3.]])

# %% [markdown]
# # Visualization of dataset points

# %%
# !pip install pyntcloud
# Out:
# Requirement already satisfied: pyntcloud in /usr/local/lib/python3.7/dist-packages (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyntcloud) (1.21.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pyntcloud) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyntcloud) (1.4.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyntcloud) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pyntcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pyntcloud) (1.15.0)

# %%
from pyntcloud import PyntCloud
import pandas as pd

# %%
df = pd.DataFrame([x.transform[:3,3] for x in X], columns = ['x','y','z'])
pntc=PyntCloud(df)

# %%
pntc.plot(return_scene=True)

# %% [markdown]
# # Seperate points of the first quarter
#
# we have to seperate the points in the positive side of x,y and z from the whole data points

# %%
def FirstQuarterPoints(X,Y):
  x = []
  y = []
  for i in range (len(X)):
    
    if (X[i].transform[:3,3])[0]>0 and (X[i].transform[:3,3])[1]>0 and (X[i].transform[:3,3])[2]>0:
      x.append(X[i])
      y.append(Y[i])
  return np.array(x),np.array(y)

# %%
X,Y=FirstQuarterPoints(X,Y)
print(X.shape)
# Out:
# (318536,)

# %%
df = pd.DataFrame([x.transform[:3,3] for x in X], columns = ['x','y','z'])
pntc=PyntCloud(df)
pntc.plot(return_scene=True)

# %% [markdown]
# # determining unreachable point's condition
#
# we can notice initially that the reachable point's is the sphere that has the center $(0,0,l_1)$ and the radius $l_2 + l_3 + l_4$
#
# so, for any given point, this condition should be satisfied :
#
# $ x^2 + y^2 + (z - l_1)^2 <= (l_2+ l_3 + l_4 - l_1)^2 $
#
# the problem will be more complicated if we consider that every actiuator has limited range of angles, but for simlicity, we will keep this assumption valid.

# %%
def InRange(p):
  if p[2]<0:
    return False
  r2 = p[0]**2 + p[1]**2 + (p[2]-l1)**2 
  if r2<= (l2 + l3 + l4 - l1)**2 :
    return True
  else :
    return False

# %% [markdown]
# # Clustering dataset points
#
# as we might think : there must be more than one configuration for the same point, this will disturb the model and brevent it from reaching global minima, so we need to make sure that our dataset has only one angles configuration for each point in space.
#
# first, we will create clustering centers, which is points with specified resolution in the first quarter, then every point in dataset will be clustered according to the closest center.
#
# we will use **KNeighborsClassifier** from **sklearn**

# %%
dl = 0.05

knnPoints = []
for i in range(int((l1+l2+l3+l4)/dl) +1):
  for j in range(int((l1+l2+l3+l4)/dl) +1):
    for k in range(int((l1+l2+l3+l4)/dl) +1):
      p= [i*dl,j*dl,k*dl]
      if InRange(p):
        knnPoints.append(p)

knnIndeces = [i for i in range(len(knnPoints))]

# %%
from pyntcloud import PyntCloud
import pandas as pd
df = pd.DataFrame(knnPoints, columns = ['x','y','z'])
pntc=PyntCloud(df)
pntc.plot(return_scene=True)

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np


nbrs = KNeighborsClassifier(n_neighbors=1)
nbrs.fit(knnPoints,knnIndeces)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
sortedPoints = {}
for i in range(len(knnPoints)):
  sortedPoints[str(i)] = {'x':[],'y':[]}

# %%
for i in range(len(X)):
  pred = nbrs.predict([X[i].transform[:3,3]])
  sortedPoints[str(pred[0])]['x'].append(X[i])
  sortedPoints[str(pred[0])]['y'].append(Y[i])

# %% [markdown]
# for now, we will choose the point with the minimum Euler x angle

# %%
X_train =[]
Y_train = []
for i in range(len(knnPoints)):
  if len(sortedPoints[str(i)]['x'])!=0:
    if len(sortedPoints[str(i)]['x']) ==1 :
      X_train.append(sortedPoints[str(i)]['x'][0].transform[:3,3].tolist())
      Y_train.append(sortedPoints[str(i)]['y'][0])
    else :
      angles = [sortedPoints[str(i)]['x'][k].ComputeAngles()[0] for k in range(len(sortedPoints[str(i)]['x']))]
      minIndex = angles.index(min(angles))
      X_train.append(sortedPoints[str(i)]['x'][minIndex].transform[:3,3].tolist())
      Y_train.append(sortedPoints[str(i)]['y'][minIndex].tolist())

X_train =np.array(X_train)
Y_train = np.array(Y_train)

# %% [markdown]
# # Normalizing data-set
#
# now we normalize angles in the selected ranges, and position to the maximum possible range

# %%
def NormalizeData (Xdata,Ydata,PMax,Ranges):
  Xdata = Xdata[:]/PMax
  offset = Ranges[:,0]
  width = Ranges[:,1]-Ranges[:,0]
  for i in range(len(Ydata)):
    Ydata[i] = (Ydata[i]-offset)/width
  return Xdata,Ydata

# %%
X,Y = NormalizeData(X_train,Y_train,l1+l2+l3+l4,ranges)

# %%
print(X)
# Out:
# [[0.078 0.004 0.996]
#  [0.005 0.091 0.994]
#  [0.006 0.117 0.989]
#  ...
#  [0.737 0.117 0.276]
#  [0.73  0.155 0.328]
#  [0.749 0.039 0.25 ]]

# %%
print(Y)
# Out:
# [[0.033 0.967 1.    1.   ]
#  [0.967 0.967 1.    0.967]
#  [0.967 0.967 1.    0.9  ]
#  ...
#  [0.1   0.533 1.    0.867]
#  [0.133 0.533 1.    1.   ]
#  [0.033 0.5   1.    1.   ]]

# %% [markdown]
# # Creating deep learning model

# %%
from tensorflow.python.keras.backend import dropout

import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import Adam

# Configuration options
feature_vector_length = 3
num_classes = 4

X_train =np.array(X) 
Y_train = np.array(Y)

# Set the input shape
input_shape = (feature_vector_length,)

# Create the model
model = Sequential()
model.add(Dense(50, input_shape=input_shape, activation='relu'))
model.add(Dropout(rate=0.4))
model.add(Dense(50, activation='relu'))
model.add(Dropout(rate=0.4))
model.add(Dense(num_classes, activation='relu'))

# Configure the model and start training

model.compile(loss='mean_squared_error', metrics=['accuracy'], optimizer=Adam(learning_rate=1e-3))
history =model.fit(X, Y, epochs=3000, batch_size=100, verbose=1, validation_split=0.1,shuffle=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8929 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 502/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8917 - val_loss: 0.0107 - val_accuracy: 0.8894
# Epoch 503/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8906 - val_loss: 0.0124 - val_accuracy: 0.8868
# Epoch 504/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8898 - val_loss: 0.0113 - val_accuracy: 0.8888
# Epoch 505/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8872 - val_loss: 0.0119 - val_accuracy: 0.8873
# Epoch 506/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 507/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0100 - val_accuracy: 0.8888
# Epoch 508/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0106 - val_accuracy: 0.8894
# Epoch 509/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8906 - val_loss: 0.0117 - val_accuracy: 0.8878
# Epoch 510/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8859 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 511/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8931 - val_loss: 0.0111 - val_accuracy: 0.8894
# Epoch 512/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8895 - val_loss: 0.0113 - val_accuracy: 0.8888
# Epoch 513/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8888 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 514/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8890 - val_loss: 0.0114 - val_accuracy: 0.8878
# Epoch 515/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8892 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 516/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8902 - val_loss: 0.0116 - val_accuracy: 0.8888
# Epoch 517/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8905 - val_loss: 0.0117 - val_accuracy: 0.8883
# Epoch 518/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.8894 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 519/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0110 - val_accuracy: 0.8888
# Epoch 520/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8945 - val_loss: 0.0109 - val_accuracy: 0.8899
# Epoch 521/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8890 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 522/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8932 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 523/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0114 - val_accuracy: 0.8894
# Epoch 524/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0104 - val_accuracy: 0.8904
# Epoch 525/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 526/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8881 - val_loss: 0.0096 - val_accuracy: 0.8909
# Epoch 527/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0114 - val_accuracy: 0.8888
# Epoch 528/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0109 - val_accuracy: 0.8904
# Epoch 529/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0099 - val_accuracy: 0.8904
# Epoch 530/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 531/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8905 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 532/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8859 - val_loss: 0.0115 - val_accuracy: 0.8888
# Epoch 533/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8917 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 534/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8904 - val_loss: 0.0118 - val_accuracy: 0.8868
# Epoch 535/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8896 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 536/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8913 - val_loss: 0.0107 - val_accuracy: 0.8894
# Epoch 537/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8871 - val_loss: 0.0104 - val_accuracy: 0.8899
# Epoch 538/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8918 - val_loss: 0.0104 - val_accuracy: 0.8909
# Epoch 539/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8899 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 540/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8891 - val_loss: 0.0116 - val_accuracy: 0.8888
# Epoch 541/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8880 - val_loss: 0.0115 - val_accuracy: 0.8883
# Epoch 542/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8875 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 543/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8882 - val_loss: 0.0107 - val_accuracy: 0.8888
# Epoch 544/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8936 - val_loss: 0.0106 - val_accuracy: 0.8899
# Epoch 545/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0098 - val_accuracy: 0.8904
# Epoch 546/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0103 - val_accuracy: 0.8904
# Epoch 547/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8895 - val_loss: 0.0109 - val_accuracy: 0.8899
# Epoch 548/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8895 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 549/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8917 - val_loss: 0.0110 - val_accuracy: 0.8904
# Epoch 550/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8883 - val_loss: 0.0129 - val_accuracy: 0.8883
# Epoch 551/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8921 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 552/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8900 - val_loss: 0.0119 - val_accuracy: 0.8894
# Epoch 553/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8861 - val_loss: 0.0110 - val_accuracy: 0.8878
# Epoch 554/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8886 - val_loss: 0.0118 - val_accuracy: 0.8873
# Epoch 555/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0111 - val_accuracy: 0.8904
# Epoch 556/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8902 - val_loss: 0.0104 - val_accuracy: 0.8904
# Epoch 557/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8864 - val_loss: 0.0102 - val_accuracy: 0.8888
# Epoch 558/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8884 - val_loss: 0.0113 - val_accuracy: 0.8899
# Epoch 559/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8904 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 560/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8891 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 561/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8917 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 562/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8921 - val_loss: 0.0115 - val_accuracy: 0.8878
# Epoch 563/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8918 - val_loss: 0.0102 - val_accuracy: 0.8899
# Epoch 564/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8901 - val_loss: 0.0106 - val_accuracy: 0.8894
# Epoch 565/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8876 - val_loss: 0.0106 - val_accuracy: 0.8914
# Epoch 566/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8878 - val_loss: 0.0114 - val_accuracy: 0.8899
# Epoch 567/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0114 - val_accuracy: 0.8899
# Epoch 568/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8919 - val_loss: 0.0119 - val_accuracy: 0.8883
# Epoch 569/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8927 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 570/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8918 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 571/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8919 - val_loss: 0.0109 - val_accuracy: 0.8899
# Epoch 572/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8885 - val_loss: 0.0103 - val_accuracy: 0.8904
# Epoch 573/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8881 - val_loss: 0.0109 - val_accuracy: 0.8899
# Epoch 574/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8891 - val_loss: 0.0091 - val_accuracy: 0.8914
# Epoch 575/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0106 - val_accuracy: 0.8894
# Epoch 576/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8930 - val_loss: 0.0107 - val_accuracy: 0.8888
# Epoch 577/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8893 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 578/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8900 - val_loss: 0.0118 - val_accuracy: 0.8883
# Epoch 579/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 580/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0101 - val_accuracy: 0.8909
# Epoch 581/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0103 - val_accuracy: 0.8894
# Epoch 582/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8897 - val_loss: 0.0101 - val_accuracy: 0.8904
# Epoch 583/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8895 - val_loss: 0.0102 - val_accuracy: 0.8909
# Epoch 584/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8900 - val_loss: 0.0098 - val_accuracy: 0.8914
# Epoch 585/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8882 - val_loss: 0.0101 - val_accuracy: 0.8919
# Epoch 586/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8933 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 587/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8902 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 588/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8852 - val_loss: 0.0108 - val_accuracy: 0.8883
# Epoch 589/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8909 - val_loss: 0.0112 - val_accuracy: 0.8894
# Epoch 590/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8898 - val_loss: 0.0108 - val_accuracy: 0.8904
# Epoch 591/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0102 - val_accuracy: 0.8894
# Epoch 592/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8890 - val_loss: 0.0111 - val_accuracy: 0.8899
# Epoch 593/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8896 - val_loss: 0.0117 - val_accuracy: 0.8868
# Epoch 594/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8918 - val_loss: 0.0105 - val_accuracy: 0.8904
# Epoch 595/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 596/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0108 - val_accuracy: 0.8888
# Epoch 597/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8865 - val_loss: 0.0115 - val_accuracy: 0.8888
# Epoch 598/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8910 - val_loss: 0.0101 - val_accuracy: 0.8909
# Epoch 599/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8924 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 600/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8902 - val_loss: 0.0113 - val_accuracy: 0.8888
# Epoch 601/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8909 - val_loss: 0.0106 - val_accuracy: 0.8894
# Epoch 602/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8902 - val_loss: 0.0100 - val_accuracy: 0.8914
# Epoch 603/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8935 - val_loss: 0.0095 - val_accuracy: 0.8919
# Epoch 604/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8867 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 605/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8890 - val_loss: 0.0107 - val_accuracy: 0.8899
# Epoch 606/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8908 - val_loss: 0.0123 - val_accuracy: 0.8873
# Epoch 607/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 608/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8923 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 609/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8870 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 610/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8850 - val_loss: 0.0111 - val_accuracy: 0.8899
# Epoch 611/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8899 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 612/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8939 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 613/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 614/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8918 - val_loss: 0.0112 - val_accuracy: 0.8894
# Epoch 615/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0111 - val_accuracy: 0.8899
# Epoch 616/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0109 - val_accuracy: 0.8904
# Epoch 617/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8876 - val_loss: 0.0112 - val_accuracy: 0.8883
# Epoch 618/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8927 - val_loss: 0.0115 - val_accuracy: 0.8894
# Epoch 619/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8914 - val_loss: 0.0113 - val_accuracy: 0.8899
# Epoch 620/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8909 - val_loss: 0.0115 - val_accuracy: 0.8888
# Epoch 621/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8896 - val_loss: 0.0102 - val_accuracy: 0.8919
# Epoch 622/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8861 - val_loss: 0.0106 - val_accuracy: 0.8904
# Epoch 623/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8907 - val_loss: 0.0104 - val_accuracy: 0.8894
# Epoch 624/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8919 - val_loss: 0.0097 - val_accuracy: 0.8919
# Epoch 625/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8892 - val_loss: 0.0114 - val_accuracy: 0.8894
# Epoch 626/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8892 - val_loss: 0.0107 - val_accuracy: 0.8888
# Epoch 627/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0111 - val_accuracy: 0.8878
# Epoch 628/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8904 - val_loss: 0.0104 - val_accuracy: 0.8904
# Epoch 629/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8893 - val_loss: 0.0111 - val_accuracy: 0.8894
# Epoch 630/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8908 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 631/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.8874 - val_loss: 0.0118 - val_accuracy: 0.8888
# Epoch 632/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0114 - val_accuracy: 0.8862
# Epoch 633/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 634/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8901 - val_loss: 0.0097 - val_accuracy: 0.8904
# Epoch 635/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 636/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8892 - val_loss: 0.0097 - val_accuracy: 0.8919
# Epoch 637/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8850 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 638/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8897 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 639/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8926 - val_loss: 0.0106 - val_accuracy: 0.8904
# Epoch 640/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8930 - val_loss: 0.0106 - val_accuracy: 0.8899
# Epoch 641/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8903 - val_loss: 0.0113 - val_accuracy: 0.8878
# Epoch 642/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8904 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 643/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8932 - val_loss: 0.0109 - val_accuracy: 0.8899
# Epoch 644/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 645/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8926 - val_loss: 0.0103 - val_accuracy: 0.8904
# Epoch 646/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8899 - val_loss: 0.0122 - val_accuracy: 0.8878
# Epoch 647/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8878 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 648/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8921 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 649/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8909 - val_loss: 0.0102 - val_accuracy: 0.8904
# Epoch 650/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8868 - val_loss: 0.0112 - val_accuracy: 0.8899
# Epoch 651/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8921 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 652/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8904 - val_loss: 0.0105 - val_accuracy: 0.8904
# Epoch 653/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8941 - val_loss: 0.0111 - val_accuracy: 0.8899
# Epoch 654/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8898 - val_loss: 0.0104 - val_accuracy: 0.8904
# Epoch 655/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8895 - val_loss: 0.0099 - val_accuracy: 0.8919
# Epoch 656/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.8895 - val_loss: 0.0101 - val_accuracy: 0.8909
# Epoch 657/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0113 - val_accuracy: 0.8899
# Epoch 658/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8917 - val_loss: 0.0114 - val_accuracy: 0.8883
# Epoch 659/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8907 - val_loss: 0.0114 - val_accuracy: 0.8883
# Epoch 660/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8957 - val_loss: 0.0101 - val_accuracy: 0.8909
# Epoch 661/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8928 - val_loss: 0.0095 - val_accuracy: 0.8919
# Epoch 662/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0106 - val_accuracy: 0.8904
# Epoch 663/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8882 - val_loss: 0.0114 - val_accuracy: 0.8857
# Epoch 664/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0109 - val_accuracy: 0.8904
# Epoch 665/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8838 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 666/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.8874 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 667/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8914 - val_loss: 0.0102 - val_accuracy: 0.8899
# Epoch 668/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8922 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 669/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8909 - val_loss: 0.0099 - val_accuracy: 0.8909
# Epoch 670/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0098 - val_accuracy: 0.8909
# Epoch 671/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8911 - val_loss: 0.0103 - val_accuracy: 0.8894
# Epoch 672/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8935 - val_loss: 0.0113 - val_accuracy: 0.8888
# Epoch 673/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0101 - val_accuracy: 0.8899
# Epoch 674/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8919 - val_loss: 0.0107 - val_accuracy: 0.8888
# Epoch 675/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0118 - val_accuracy: 0.8878
# Epoch 676/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8886 - val_loss: 0.0103 - val_accuracy: 0.8888
# Epoch 677/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8884 - val_loss: 0.0117 - val_accuracy: 0.8873
# Epoch 678/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8913 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 679/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 680/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8895 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 681/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8895 - val_loss: 0.0113 - val_accuracy: 0.8878
# Epoch 682/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8931 - val_loss: 0.0121 - val_accuracy: 0.8868
# Epoch 683/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8885 - val_loss: 0.0101 - val_accuracy: 0.8899
# Epoch 684/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8893 - val_loss: 0.0092 - val_accuracy: 0.8925
# Epoch 685/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8867 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 686/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8892 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 687/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8910 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 688/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8903 - val_loss: 0.0102 - val_accuracy: 0.8899
# Epoch 689/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8930 - val_loss: 0.0097 - val_accuracy: 0.8925
# Epoch 690/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8878 - val_loss: 0.0111 - val_accuracy: 0.8883
# Epoch 691/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8945 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 692/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8899 - val_loss: 0.0110 - val_accuracy: 0.8888
# Epoch 693/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8932 - val_loss: 0.0110 - val_accuracy: 0.8888
# Epoch 694/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8924 - val_loss: 0.0112 - val_accuracy: 0.8883
# Epoch 695/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8885 - val_loss: 0.0112 - val_accuracy: 0.8878
# Epoch 696/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0099 - val_accuracy: 0.8899
# Epoch 697/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8920 - val_loss: 0.0118 - val_accuracy: 0.8888
# Epoch 698/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0103 - val_accuracy: 0.8904
# Epoch 699/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8907 - val_loss: 0.0114 - val_accuracy: 0.8888
# Epoch 700/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8917 - val_loss: 0.0115 - val_accuracy: 0.8883
# Epoch 701/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8884 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 702/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0107 - val_accuracy: 0.8894
# Epoch 703/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8902 - val_loss: 0.0116 - val_accuracy: 0.8888
# Epoch 704/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8935 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 705/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8918 - val_loss: 0.0107 - val_accuracy: 0.8894
# Epoch 706/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8886 - val_loss: 0.0114 - val_accuracy: 0.8888
# Epoch 707/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8931 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 708/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8895 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 709/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8880 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 710/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8923 - val_loss: 0.0107 - val_accuracy: 0.8904
# Epoch 711/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8931 - val_loss: 0.0117 - val_accuracy: 0.8878
# Epoch 712/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8896 - val_loss: 0.0119 - val_accuracy: 0.8894
# Epoch 713/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8899 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 714/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0094 - val_accuracy: 0.8935
# Epoch 715/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8912 - val_loss: 0.0124 - val_accuracy: 0.8857
# Epoch 716/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8916 - val_loss: 0.0112 - val_accuracy: 0.8883
# Epoch 717/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8903 - val_loss: 0.0110 - val_accuracy: 0.8888
# Epoch 718/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8934 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 719/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8930 - val_loss: 0.0112 - val_accuracy: 0.8894
# Epoch 720/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8968 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 721/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8889 - val_loss: 0.0113 - val_accuracy: 0.8894
# Epoch 722/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8893 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 723/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8921 - val_loss: 0.0108 - val_accuracy: 0.8904
# Epoch 724/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.8905 - val_loss: 0.0108 - val_accuracy: 0.8878
# Epoch 725/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8912 - val_loss: 0.0103 - val_accuracy: 0.8904
# Epoch 726/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8920 - val_loss: 0.0104 - val_accuracy: 0.8899
# Epoch 727/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8899 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 728/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8913 - val_loss: 0.0114 - val_accuracy: 0.8868
# Epoch 729/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8920 - val_loss: 0.0124 - val_accuracy: 0.8836
# Epoch 730/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0107 - val_accuracy: 0.8899
# Epoch 731/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8874 - val_loss: 0.0100 - val_accuracy: 0.8904
# Epoch 732/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8901 - val_loss: 0.0121 - val_accuracy: 0.8868
# Epoch 733/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8889 - val_loss: 0.0116 - val_accuracy: 0.8857
# Epoch 734/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0110 - val_accuracy: 0.8888
# Epoch 735/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0101 - val_accuracy: 0.8899
# Epoch 736/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8935 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 737/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0120 - val_accuracy: 0.8868
# Epoch 738/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8896 - val_loss: 0.0107 - val_accuracy: 0.8899
# Epoch 739/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8884 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 740/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8944 - val_loss: 0.0108 - val_accuracy: 0.8888
# Epoch 741/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8882 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 742/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8909 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 743/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8933 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 744/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0115 - val_accuracy: 0.8888
# Epoch 745/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0098 - val_accuracy: 0.8904
# Epoch 746/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8888 - val_loss: 0.0100 - val_accuracy: 0.8909
# Epoch 747/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8880 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 748/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8894 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 749/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8899 - val_loss: 0.0102 - val_accuracy: 0.8904
# Epoch 750/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 751/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8918 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 752/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8894 - val_loss: 0.0130 - val_accuracy: 0.8873
# Epoch 753/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8888 - val_loss: 0.0117 - val_accuracy: 0.8862
# Epoch 754/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8921 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 755/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8911 - val_loss: 0.0111 - val_accuracy: 0.8883
# Epoch 756/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8912 - val_loss: 0.0112 - val_accuracy: 0.8899
# Epoch 757/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 758/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8905 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 759/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8933 - val_loss: 0.0107 - val_accuracy: 0.8899
# Epoch 760/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8927 - val_loss: 0.0105 - val_accuracy: 0.8904
# Epoch 761/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8930 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 762/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8867 - val_loss: 0.0104 - val_accuracy: 0.8904
# Epoch 763/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8892 - val_loss: 0.0120 - val_accuracy: 0.8878
# Epoch 764/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 765/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8893 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 766/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8922 - val_loss: 0.0116 - val_accuracy: 0.8862
# Epoch 767/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8908 - val_loss: 0.0117 - val_accuracy: 0.8883
# Epoch 768/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8907 - val_loss: 0.0114 - val_accuracy: 0.8888
# Epoch 769/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8912 - val_loss: 0.0114 - val_accuracy: 0.8894
# Epoch 770/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8903 - val_loss: 0.0096 - val_accuracy: 0.8919
# Epoch 771/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8906 - val_loss: 0.0109 - val_accuracy: 0.8894
# Epoch 772/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8891 - val_loss: 0.0106 - val_accuracy: 0.8899
# Epoch 773/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8883 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 774/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8907 - val_loss: 0.0114 - val_accuracy: 0.8888
# Epoch 775/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8876 - val_loss: 0.0107 - val_accuracy: 0.8899
# Epoch 776/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8939 - val_loss: 0.0106 - val_accuracy: 0.8899
# Epoch 777/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8886 - val_loss: 0.0108 - val_accuracy: 0.8888
# Epoch 778/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8903 - val_loss: 0.0106 - val_accuracy: 0.8899
# Epoch 779/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0105 - val_accuracy: 0.8888
# Epoch 780/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8919 - val_loss: 0.0117 - val_accuracy: 0.8873
# Epoch 781/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8902 - val_loss: 0.0108 - val_accuracy: 0.8904
# Epoch 782/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8902 - val_loss: 0.0116 - val_accuracy: 0.8888
# Epoch 783/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8920 - val_loss: 0.0107 - val_accuracy: 0.8894
# Epoch 784/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8911 - val_loss: 0.0104 - val_accuracy: 0.8899
# Epoch 785/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0117 - val_accuracy: 0.8883
# Epoch 786/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8922 - val_loss: 0.0125 - val_accuracy: 0.8836
# Epoch 787/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8901 - val_loss: 0.0112 - val_accuracy: 0.8883
# Epoch 788/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8934 - val_loss: 0.0107 - val_accuracy: 0.8888
# Epoch 789/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8913 - val_loss: 0.0118 - val_accuracy: 0.8857
# Epoch 790/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8934 - val_loss: 0.0119 - val_accuracy: 0.8857
# Epoch 791/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.8883 - val_loss: 0.0116 - val_accuracy: 0.8878
# Epoch 792/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0099 - val_accuracy: 0.8909
# Epoch 793/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8891 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 794/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0110 - val_accuracy: 0.8894
# Epoch 795/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8870 - val_loss: 0.0106 - val_accuracy: 0.8904
# Epoch 796/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8905 - val_loss: 0.0120 - val_accuracy: 0.8868
# Epoch 797/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8893 - val_loss: 0.0105 - val_accuracy: 0.8909
# Epoch 798/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0111 - val_accuracy: 0.8894
# Epoch 799/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8892 - val_loss: 0.0112 - val_accuracy: 0.8904
# Epoch 800/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8875 - val_loss: 0.0117 - val_accuracy: 0.8862
# Epoch 801/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8880 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 802/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0105 - val_accuracy: 0.8904
# Epoch 803/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8882 - val_loss: 0.0113 - val_accuracy: 0.8899
# Epoch 804/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8860 - val_loss: 0.0104 - val_accuracy: 0.8914
# Epoch 805/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8867 - val_loss: 0.0120 - val_accuracy: 0.8868
# Epoch 806/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8896 - val_loss: 0.0089 - val_accuracy: 0.8940
# Epoch 807/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8883 - val_loss: 0.0115 - val_accuracy: 0.8868
# Epoch 808/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8889 - val_loss: 0.0096 - val_accuracy: 0.8914
# Epoch 809/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8932 - val_loss: 0.0111 - val_accuracy: 0.8888
# Epoch 810/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8919 - val_loss: 0.0101 - val_accuracy: 0.8925
# Epoch 811/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8873 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 812/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8926 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 813/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8882 - val_loss: 0.0101 - val_accuracy: 0.8904
# Epoch 814/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0115 - val_accuracy: 0.8894
# Epoch 815/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8891 - val_loss: 0.0116 - val_accuracy: 0.8857
# Epoch 816/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8887 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 817/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8900 - val_loss: 0.0111 - val_accuracy: 0.8904
# Epoch 818/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8933 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 819/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0100 - val_accuracy: 0.8909
# Epoch 820/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8928 - val_loss: 0.0101 - val_accuracy: 0.8904
# Epoch 821/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8936 - val_loss: 0.0105 - val_accuracy: 0.8909
# Epoch 822/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8950 - val_loss: 0.0108 - val_accuracy: 0.8899
# Epoch 823/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8879 - val_loss: 0.0096 - val_accuracy: 0.8904
# Epoch 824/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8886 - val_loss: 0.0112 - val_accuracy: 0.8888
# Epoch 825/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.8934 - val_loss: 0.0108 - val_accuracy: 0.8894
# Epoch 826/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8902 - val_loss: 0.0096 - val_accuracy: 0.8925
# Epoch 827/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.8893 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 828/3000
# 174/174 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.8886 - val_loss: 0.0103 - val_accuracy: 0.8899
# Epoch 829/3000
# ...
# Epoch 2893/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8904 - val_loss: 0.0108 - val_accuracy: 0.8873
# Epoch 2894/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8936 - val_loss: 0.0111 - val_accuracy: 0.8868
# Epoch 2895/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8906 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 2896/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0117 - val_accuracy: 0.8852
# Epoch 2897/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8925 - val_loss: 0.0117 - val_accuracy: 0.8883
# Epoch 2898/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0128 - val_accuracy: 0.8842
# Epoch 2899/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8991 - val_loss: 0.0122 - val_accuracy: 0.8847
# Epoch 2900/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8922 - val_loss: 0.0123 - val_accuracy: 0.8847
# Epoch 2901/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8965 - val_loss: 0.0110 - val_accuracy: 0.8862
# Epoch 2902/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8900 - val_loss: 0.0115 - val_accuracy: 0.8857
# Epoch 2903/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8930 - val_loss: 0.0112 - val_accuracy: 0.8873
# Epoch 2904/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8899 - val_loss: 0.0120 - val_accuracy: 0.8852
# Epoch 2905/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8935 - val_loss: 0.0126 - val_accuracy: 0.8868
# Epoch 2906/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8893 - val_loss: 0.0115 - val_accuracy: 0.8857
# Epoch 2907/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8885 - val_loss: 0.0120 - val_accuracy: 0.8857
# Epoch 2908/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8920 - val_loss: 0.0118 - val_accuracy: 0.8857
# Epoch 2909/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8879 - val_loss: 0.0115 - val_accuracy: 0.8883
# Epoch 2910/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8943 - val_loss: 0.0113 - val_accuracy: 0.8857
# Epoch 2911/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8886 - val_loss: 0.0124 - val_accuracy: 0.8868
# Epoch 2912/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8949 - val_loss: 0.0122 - val_accuracy: 0.8836
# Epoch 2913/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8902 - val_loss: 0.0123 - val_accuracy: 0.8831
# Epoch 2914/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8904 - val_loss: 0.0110 - val_accuracy: 0.8873
# Epoch 2915/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0120 - val_accuracy: 0.8847
# Epoch 2916/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8896 - val_loss: 0.0109 - val_accuracy: 0.8883
# Epoch 2917/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 0.8900 - val_loss: 0.0126 - val_accuracy: 0.8826
# Epoch 2918/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8904 - val_loss: 0.0110 - val_accuracy: 0.8883
# Epoch 2919/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8914 - val_loss: 0.0121 - val_accuracy: 0.8847
# Epoch 2920/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8906 - val_loss: 0.0116 - val_accuracy: 0.8868
# Epoch 2921/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8921 - val_loss: 0.0119 - val_accuracy: 0.8868
# Epoch 2922/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0120 - val_accuracy: 0.8852
# Epoch 2923/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8891 - val_loss: 0.0114 - val_accuracy: 0.8878
# Epoch 2924/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8927 - val_loss: 0.0119 - val_accuracy: 0.8873
# Epoch 2925/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8912 - val_loss: 0.0117 - val_accuracy: 0.8868
# Epoch 2926/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8888 - val_loss: 0.0119 - val_accuracy: 0.8873
# Epoch 2927/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8916 - val_loss: 0.0110 - val_accuracy: 0.8899
# Epoch 2928/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8944 - val_loss: 0.0111 - val_accuracy: 0.8894
# Epoch 2929/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8894 - val_loss: 0.0117 - val_accuracy: 0.8873
# Epoch 2930/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8931 - val_loss: 0.0109 - val_accuracy: 0.8873
# Epoch 2931/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8915 - val_loss: 0.0124 - val_accuracy: 0.8847
# Epoch 2932/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8923 - val_loss: 0.0115 - val_accuracy: 0.8862
# Epoch 2933/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8924 - val_loss: 0.0109 - val_accuracy: 0.8873
# Epoch 2934/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8886 - val_loss: 0.0113 - val_accuracy: 0.8857
# Epoch 2935/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8927 - val_loss: 0.0119 - val_accuracy: 0.8842
# Epoch 2936/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8887 - val_loss: 0.0120 - val_accuracy: 0.8836
# Epoch 2937/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0103 - val_accuracy: 0.8894
# Epoch 2938/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8924 - val_loss: 0.0100 - val_accuracy: 0.8909
# Epoch 2939/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0108 - val_accuracy: 0.8868
# Epoch 2940/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8940 - val_loss: 0.0116 - val_accuracy: 0.8862
# Epoch 2941/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8929 - val_loss: 0.0120 - val_accuracy: 0.8831
# Epoch 2942/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8921 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 2943/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8930 - val_loss: 0.0113 - val_accuracy: 0.8873
# Epoch 2944/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 0.8926 - val_loss: 0.0118 - val_accuracy: 0.8862
# Epoch 2945/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0108 - val_accuracy: 0.8883
# Epoch 2946/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0107 - val_accuracy: 0.8868
# Epoch 2947/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8899 - val_loss: 0.0117 - val_accuracy: 0.8847
# Epoch 2948/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0065 - accuracy: 0.8924 - val_loss: 0.0118 - val_accuracy: 0.8852
# Epoch 2949/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8918 - val_loss: 0.0116 - val_accuracy: 0.8857
# Epoch 2950/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8911 - val_loss: 0.0109 - val_accuracy: 0.8883
# Epoch 2951/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8885 - val_loss: 0.0105 - val_accuracy: 0.8904
# Epoch 2952/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 0.8923 - val_loss: 0.0106 - val_accuracy: 0.8873
# Epoch 2953/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0123 - val_accuracy: 0.8816
# Epoch 2954/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8920 - val_loss: 0.0118 - val_accuracy: 0.8852
# Epoch 2955/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8922 - val_loss: 0.0114 - val_accuracy: 0.8873
# Epoch 2956/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8900 - val_loss: 0.0103 - val_accuracy: 0.8894
# Epoch 2957/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8928 - val_loss: 0.0111 - val_accuracy: 0.8857
# Epoch 2958/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8902 - val_loss: 0.0129 - val_accuracy: 0.8836
# Epoch 2959/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8922 - val_loss: 0.0113 - val_accuracy: 0.8862
# Epoch 2960/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8922 - val_loss: 0.0115 - val_accuracy: 0.8852
# Epoch 2961/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8913 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 2962/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8940 - val_loss: 0.0114 - val_accuracy: 0.8878
# Epoch 2963/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8917 - val_loss: 0.0109 - val_accuracy: 0.8878
# Epoch 2964/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8915 - val_loss: 0.0116 - val_accuracy: 0.8857
# Epoch 2965/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8919 - val_loss: 0.0113 - val_accuracy: 0.8883
# Epoch 2966/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8879 - val_loss: 0.0114 - val_accuracy: 0.8852
# Epoch 2967/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8886 - val_loss: 0.0114 - val_accuracy: 0.8857
# Epoch 2968/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8883 - val_loss: 0.0120 - val_accuracy: 0.8831
# Epoch 2969/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8926 - val_loss: 0.0127 - val_accuracy: 0.8826
# Epoch 2970/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8909 - val_loss: 0.0119 - val_accuracy: 0.8847
# Epoch 2971/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8901 - val_loss: 0.0113 - val_accuracy: 0.8868
# Epoch 2972/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8894 - val_loss: 0.0125 - val_accuracy: 0.8790
# Epoch 2973/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8896 - val_loss: 0.0109 - val_accuracy: 0.8888
# Epoch 2974/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8944 - val_loss: 0.0113 - val_accuracy: 0.8852
# Epoch 2975/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8911 - val_loss: 0.0117 - val_accuracy: 0.8847
# Epoch 2976/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8916 - val_loss: 0.0115 - val_accuracy: 0.8868
# Epoch 2977/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8932 - val_loss: 0.0116 - val_accuracy: 0.8862
# Epoch 2978/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8898 - val_loss: 0.0108 - val_accuracy: 0.8862
# Epoch 2979/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8931 - val_loss: 0.0109 - val_accuracy: 0.8857
# Epoch 2980/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8901 - val_loss: 0.0116 - val_accuracy: 0.8852
# Epoch 2981/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8899 - val_loss: 0.0111 - val_accuracy: 0.8868
# Epoch 2982/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8920 - val_loss: 0.0120 - val_accuracy: 0.8847
# Epoch 2983/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8932 - val_loss: 0.0108 - val_accuracy: 0.8868
# Epoch 2984/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8930 - val_loss: 0.0112 - val_accuracy: 0.8878
# Epoch 2985/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8874 - val_loss: 0.0109 - val_accuracy: 0.8868
# Epoch 2986/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8875 - val_loss: 0.0105 - val_accuracy: 0.8894
# Epoch 2987/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8871 - val_loss: 0.0106 - val_accuracy: 0.8888
# Epoch 2988/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8912 - val_loss: 0.0115 - val_accuracy: 0.8857
# Epoch 2989/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8924 - val_loss: 0.0108 - val_accuracy: 0.8868
# Epoch 2990/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0066 - accuracy: 0.8906 - val_loss: 0.0106 - val_accuracy: 0.8873
# Epoch 2991/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8936 - val_loss: 0.0110 - val_accuracy: 0.8873
# Epoch 2992/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8905 - val_loss: 0.0112 - val_accuracy: 0.8878
# Epoch 2993/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8912 - val_loss: 0.0104 - val_accuracy: 0.8894
# Epoch 2994/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8885 - val_loss: 0.0116 - val_accuracy: 0.8862
# Epoch 2995/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.8906 - val_loss: 0.0113 - val_accuracy: 0.8878
# Epoch 2996/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.8915 - val_loss: 0.0113 - val_accuracy: 0.8857
# Epoch 2997/3000
# 174/174 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 0.8908 - val_loss: 0.0113 - val_accuracy: 0.8852
# Epoch 2998/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8870 - val_loss: 0.0115 - val_accuracy: 0.8862
# Epoch 2999/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8911 - val_loss: 0.0105 - val_accuracy: 0.8899
# Epoch 3000/3000
# 174/174 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.8936 - val_loss: 0.0122 - val_accuracy: 0.8821

# %%
import matplotlib.pyplot as plt
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Test the model after training
test_results = model.evaluate(X, Y, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# 602/602 [==============================] - 1s 1ms/step - loss: 0.0047 - accuracy: 0.9213
# Test results - Loss: 0.004701337311416864 - Accuracy: 0.9213302135467529%
